# %%
import pandas
import matplotlib.pyplot as plt
import pandas as pd

test = pd.DataFrame({'a': [1, 2, 3], 'b': [0, 1, 1]})

# %%
test['b'].sum()
# Out:
# 2

# %%
plt.bar([1], test['b'].sum())
# Out:
# <BarContainer object of 1 artists>
